# %% [markdown]
# Classification Trees:
#
# 1. Gini impurity: 0 is the best feature
#
#
# ![image.png](attachment:image.png)
#
#
# Total Gini impurity is weighted average of Gini impurities of the leaves
#
#
# ![image-2.png](attachment:image-2.png)
#
# The least Gini impurity will be used as the node and then it will go down to the next least gini impurity feature
